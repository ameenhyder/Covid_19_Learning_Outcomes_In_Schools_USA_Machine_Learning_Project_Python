# %%
# Import required libraries. No other libraries are required for this task.

import pandas as pd
import numpy as np

# %%
#### analyzing 1 file of Colorado Data

path = "C:/Users/ameen.hyder/Desktop/gigs/Covid_learning_gap_ML_project_17_oct/datasets/colarado"

df1_path = path + "/2021_colarado.xlsx" 
df1 = pd.read_excel(df1_path)

df1.head()
# Out:
#    Level  District Code  District Name  School Code  School Name  \
# 0  STATE              0  All Districts            0  All Schools
# 1  STATE              0  All Districts            0  All Schools
# 2  STATE              0  All Districts            0  All Schools
# 3  STATE              0  All Districts            0  All Schools
# 4  STATE              0  All Districts            0  All Schools
#
#                  Content  Grade Number of Total Records  \
# 0  English Language Arts      3                  59,309
# 1  Spanish Language Arts      3                   1,418
# 2  English Language Arts      5                  63,057
# 3  English Language Arts      7                  67,442
# 4            Mathematics      4                  61,785
#
#   Number of Valid Scores Number of No Scores  ...  \
# 0                 45,187              14,122  ...
# 1                    837                 581  ...
# 2                 46,909              16,148  ...
# ...

# %%
df1.columns
# Out:
# Index(['Level', 'District Code', 'District Name', 'School Code', 'School Name',
#        'Content', 'Test/Grade', '# of Total Records', '# of Valid Scores',
#        '# of No Scores', 'Participation Rate', 'Mean Scale Score',
#        '# Did Not Yet Meet Expectations', '% Did Not Yet Meet Expectations',
#        '# Partially Met Expectations', '% Partially Met Expectations',
#        '# Approached Expectations', '% Approached Expectations',
#        '# Met Expectations', '% Met Expectations', '# Exceeded Expectations',
#        '% Exceeded Expectations', '# Met or Exceeded Expectations',
#        '% Met or Exceeded Expectations', '2017 Mean Scale Score**',
#        '2017 # Met or Exceeded Expectations**',
#        '2017 % Met or Exceeded Expectations**',
#        '% Change in Met or Exceeded Expectations**'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16180 entries, 0 to 16179
# Data columns (total 28 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Level                                       16180 non-null  object
#  1   District Code                               16180 non-null  int64
#  2   District Name                               16180 non-null  object
#  3   School Code                                 16180 non-null  int64
#  4   School Name                                 16180 non-null  object
#  5   Content                                     16180 non-null  object
#  6   Test/Grade                                  16180 non-null  object
#  7   # of Total Records                          16180 non-null  object
#  8   # of Valid Scores                           16180 non-null  object
#  9   # of No Scores                              16180 non-null  object
# ...

# %%
relevant_col = ['Level','District Code','District Name', 'School Name','Content', 'Test/Grade','Mean Scale Score']

df2 = df1[relevant_col]
df2.head()
# Out:
#    Level  District Code  District Name  School Name                Content  \
# 0  STATE              0  All Districts  All Schools  English Language Arts
# 1  STATE              0  All Districts  All Schools  English Language Arts
# 2  STATE              0  All Districts  All Schools  English Language Arts
# 3  STATE              0  All Districts  All Schools  English Language Arts
# 4  STATE              0  All Districts  All Schools  English Language Arts
#
#                        Test/Grade Mean Scale Score
# 0                      All Grades              743
# 1  English Language Arts Grade 03              739
# 2  English Language Arts Grade 04              745
# 3  English Language Arts Grade 05              746
# 4  English Language Arts Grade 06              743

# %%
for col in df2:
    print(df2[col].unique())
    
    
## mean scale score has star value that needs to be removed
# Out:
# ['STATE' 'DISTRICT' 'SCHOOL']
# [   0 1040   20   30  180  960 1620 3030  100  220 3040 1450 2640 3145
#  1530   50 1490  940  480 1750 3146 2395  490 1860 1500  190  970  270
#  1140  640 2810 8001 2560  130  520 1020  540 9170 9000 1010 1160 2010
#  3010  770  860 1980  170 2730  870  880  890 2055  900 1520 1430  910
#  1350 2520 3085 1120  950  920 1050  120 1570 9130 1110 2405 1000 2540
#  1150 1850 1220 1195 1780 1330 2650 3120 1360 1070  980 2630 2760 1460
#  1380 1600 2670 2620 1390 3220 1540 1420 3110 2862 1810 1760  930  510
#  1400 1510 2660  290 1080 3230 1790  140 3060 2070 1030 2535   10  310
#  2710 2000 1130 2800 2020 2740 2035 2180 2790  550 1410 2840 3050 2580
#  2610 3148 1060 1440 1870 1990 2600 3130 1550 3147 1590  240 2690 2700
#  2720 2865 2590 1180 2530  500 9050  560  110 2750   40  123  740 2820
#   580 2780  250  470 2770   60 1480 3000 2570 2830 1560 1580 1828  260
#   230 3080 3140 3090 2505 2190 1340   70  990 2515 2680 3100 3020 3070
#  3210 3200]
# ...

# %%
for col in df2:
    print("couunt of NA values in", col)
    print(df2[col].isnull().sum())
# Out:
# couunt of NA values in Level
# 0
# couunt of NA values in District Code
# 0
# couunt of NA values in District Name
# 0
# couunt of NA values in School Name
# 0
# couunt of NA values in Content
# 0
# couunt of NA values in Test/Grade
# 0
# couunt of NA values in Mean Scale Score
# 0

# %%
df2.info()

## mean scale score needs to be converted to int value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16180 entries, 0 to 16179
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Level             16180 non-null  object
#  1   District Code     16180 non-null  int64
#  2   District Name     16180 non-null  object
#  3   School Name       16180 non-null  object
#  4   Content           16180 non-null  object
#  5   Test/Grade        16180 non-null  object
#  6   Mean Scale Score  16180 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 885.0+ KB
